# %%
# Import Dependacies
from bs4 import BeautifulSoup as soup
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager

# %%
#Set up splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

#Visit URL
url = 'https://redplanetscience.com/'
browser.visit(url)
# Out:
# [WDM] - Downloading: 100%|██████████| 6.46M/6.46M [00:28<00:00, 236kB/s]

# %%
#Setup BeautifulSoup
html = browser.html
html_soup = soup(html, 'html.parser')

# %%
container = html_soup.findAll('div', id='news')
container
# Out:
# [<div class="container" id="news">
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8511_PIA23279-226.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">November 22, 2022</div>
#  <div class="content_title">Deadline Closing for Names to Fly on NASA's Next Mars Rover</div>
#  <div class="article_teaser_body">You have until Sept. 30 to send your names to Mars aboard the Mars 2020 rover. </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8719_launch-at-home-320.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">November 21, 2022</div>
#  <div class="content_title">NASA Invites Public to Share Excitement of Mars 2020 Perseverance Rover Launch</div>
#  <div class="article_teaser_body">There are lots of ways to participate in the historic event, which is targeted for July 30.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8726_PIA23898-320.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">November 17, 2022</div>
#  <div class="content_title">8 Martian Postcards to Celebrate Curiosity's Landing Anniversary</div>
#  <div class="article_teaser_body">The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8512_PIA23463-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">November 16, 2022</div>
#  <div class="content_title">NASA Mars Mission Connects With Bosnian and Herzegovinian Town</div>
#  <div class="article_teaser_body">A letter from NASA was presented to the mayor of Jezero, Bosnia-Herzegovina, honoring the connection between the town and Jezero Crater, the Mars 2020 rover landing site.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8613_InSight-Nature-papers-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">November 11, 2022</div>
#  <div class="content_title">A Year of Surprising Science From NASA's InSight Mars Mission</div>
#  <div class="article_teaser_body">A batch of new papers summarizes the lander's findings above and below the surface of the Red Planet.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8603_list_image.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">November 11, 2022</div>
#  <div class="content_title">NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget</div>
#  <div class="article_teaser_body">Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8649_PIA23828-MAINimage-RoverNamePlate-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">November 6, 2022</div>
#  <div class="content_title">NASA's Perseverance Mars Rover Gets Balanced</div>
#  <div class="article_teaser_body">The mission team performed a crucial weight-balancing test on the rover in preparation for this summer's history-making launch to the Red Planet.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8682_SCS-16-MAIN-320.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">November 5, 2022</div>
#  <div class="content_title">The Extraordinary Sample-Gathering System of NASA's Perseverance Mars Rover</div>
#  <div class="article_teaser_body">Two astronauts collected Moon rocks on Apollo 11. It will take three robotic systems working together to gather up the first Mars rock samples for return to Earth.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8561_MarCO-32x24.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">November 3, 2022</div>
#  <div class="content_title">NASA's Briefcase-Size MarCO Satellite Picks Up Honors</div>
#  <div class="article_teaser_body">The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week &amp; Space Technology.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8596_mavenatmars-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">November 1, 2022</div>
#  <div class="content_title">NASA's MAVEN Explores Mars to Understand Radio Interference at Earth</div>
#  <div class="article_teaser_body">NASA’s MAVEN spacecraft has discovered “layers” and “rifts” in the electrically charged part of the upper atmosphere of Mars.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8765_PIA24040-320.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">October 31, 2022</div>
#  <div class="content_title">AI Is Helping Scientists Discover Fresh Craters on Mars</div>
#  <div class="article_teaser_body">It's the first time machine learning has been used to find previously unknown craters on the Red Planet.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8749_PIA23964-320.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">October 27, 2022</div>
#  <div class="content_title">NASA Readies Perseverance Mars Rover's Earthly Twin </div>
#  <div class="article_teaser_body">Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8537_PIA23468-16_320x240px.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">October 25, 2022</div>
#  <div class="content_title">Mars 2020 Stands on Its Own Six Wheels</div>
#  <div class="article_teaser_body">In time-lapse video, taken at JPL, captures the first time NASA's Mars 2020 rover carries its full weight on its legs and wheels.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8619_8588_name20190625-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">October 25, 2022</div>
#  <div class="content_title">NASA to Reveal Name of Its Next Mars Rover</div>
#  <div class="article_teaser_body">After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-12">
#  <hr/>
#  <div class="row">
#  <div class="col-md-4">
#  <div class="list_image">
#  <img src="https://mars.nasa.gov/system/news_items/list_view_images/8575_PIA23519-SAF-unannot-320x240.jpg"/>
#  </div>
#  </div>
#  <div class="col-md-8">
#  <div class="list_text">
#  <div class="list_date">October 21, 2022</div>
#  <div class="content_title">Space History Is Made in This NASA Robot Factory</div>
#  <div class="article_teaser_body">From rockets to rovers, JPL's Spacecraft Assembly Facility has been at the center of robotic spaceflight. Here's a closer look at what makes it so special.</div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>]

# %%
# Loop through and gather all titles and summary from webpage
for row in container:
    titles =html_soup.findAll('div', class_='content_title')
    summaries=html_soup.findAll('div', class_='article_teaser_body')
    
doc_info = {
    'title':titles,
    'summary':summaries
}
    
print(doc_info)
# Out:
# {'title': [<div class="content_title">Deadline Closing for Names to Fly on NASA's Next Mars Rover</div>, <div class="content_title">NASA Invites Public to Share Excitement of Mars 2020 Perseverance Rover Launch</div>, <div class="content_title">8 Martian Postcards to Celebrate Curiosity's Landing Anniversary</div>, <div class="content_title">NASA Mars Mission Connects With Bosnian and Herzegovinian Town</div>, <div class="content_title">A Year of Surprising Science From NASA's InSight Mars Mission</div>, <div class="content_title">NASA Administrator Statement on Moon to Mars Initiative, FY 2021 Budget</div>, <div class="content_title">NASA's Perseverance Mars Rover Gets Balanced</div>, <div class="content_title">The Extraordinary Sample-Gathering System of NASA's Perseverance Mars Rover</div>, <div class="content_title">NASA's Briefcase-Size MarCO Satellite Picks Up Honors</div>, <div class="content_title">NASA's MAVEN Explores Mars to Understand Radio Interference at Earth</div>, <div class="content_title">AI Is Helping Scientists Discover Fresh Craters on Mars</div>, <div class="content_title">NASA Readies Perseverance Mars Rover's Earthly Twin </div>, <div class="content_title">Mars 2020 Stands on Its Own Six Wheels</div>, <div class="content_title">NASA to Reveal Name of Its Next Mars Rover</div>, <div class="content_title">Space History Is Made in This NASA Robot Factory</div>], 'summary': [<div class="article_teaser_body">You have until Sept. 30 to send your names to Mars aboard the Mars 2020 rover. </div>, <div class="article_teaser_body">There are lots of ways to participate in the historic event, which is targeted for July 30.</div>, <div class="article_teaser_body">The NASA rover touched down eight years ago, on Aug. 5, 2012, and will soon be joined by a second rover, Perseverance.</div>, <div class="article_teaser_body">A letter from NASA was presented to the mayor of Jezero, Bosnia-Herzegovina, honoring the connection between the town and Jezero Crater, the Mars 2020 rover landing site.</div>, <div class="article_teaser_body">A batch of new papers summarizes the lander's findings above and below the surface of the Red Planet.</div>, <div class="article_teaser_body">Jim Bridenstine addresses NASA's ambitious plans for the coming years, including Mars Sample Return.</div>, <div class="article_teaser_body">The mission team performed a crucial weight-balancing test on the rover in preparation for this summer's history-making launch to the Red Planet.</div>, <div class="article_teaser_body">Two astronauts collected Moon rocks on Apollo 11. It will take three robotic systems working together to gather up the first Mars rock samples for return to Earth.</div>, <div class="article_teaser_body">The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week &amp; Space Technology.</div>, <div class="article_teaser_body">NASA’s MAVEN spacecraft has discovered “layers” and “rifts” in the electrically charged part of the upper atmosphere of Mars.</div>, <div class="article_teaser_body">It's the first time machine learning has been used to find previously unknown craters on the Red Planet.</div>, <div class="article_teaser_body">Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape.</div>, <div class="article_teaser_body">In time-lapse video, taken at JPL, captures the first time NASA's Mars 2020 rover carries its full weight on its legs and wheels.</div>, <div class="article_teaser_body">After a months-long contest among students to name NASA's newest Mars rover, the agency will reveal the winning name — and the winning student — this Thursday. </div>, <div class="article_teaser_body">From rockets to rovers, JPL's Spacecraft Assembly Facility has been at the center of robotic spaceflight. Here's a closer look at what makes it so special.</div>]}
